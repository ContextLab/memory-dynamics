# %%
import supereeg as se
import neurosynth as ns
import nibabel as nb
import nilearn as nl
import numpy as np
import cortex
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = nb.load('../../data/brains/away_from_volume.nii.gz')
target_vox_size = np.multiply(x.header.get_zooms()[0:3], np.divide((91, 100, 91), x.shape[0:3]))
#x = nl.image.index_img(x, 0)

# %%
x_mni = nb.load('../../data/brains/away_from_mni.nii.gz')

# %%
std_brain = se.helpers._std((2,2,2))

# %%
# y = se.helpers._resample_nii(x, (2, 2, 2))
# y = se.helpers._resample_nii(x, tuple(target_vox_size))

# y = nl.image.resample_img(x_mni, target_affine=std_brain.affine, target_shape=std_brain.shape)
# z = nl.image.coord_transform(y[:], y.shape[1], y.shape[2], affine=std_brain.affine)
# z = nl.image.resample_to_img(y, std_brain.)

# %%
nl.plotting.plot_glass_brain(x_mni)

# %%
nl.plotting.plot_glass_brain(std_brain)

# %%
cortex.align.automatic('S1', 'example-transform', './ref-image.nii.gz')
# Out:
# FLIRT pre-alignment
# Running BBR
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-ae6b53ef2f82> in <module>()
# ----> 1 cortex.align.automatic('S1', 'example-transform', './ref-image.nii.gz')
#
# ~/Documents/Dartmouth/Thesis/memory-dynamics/code/pycortex/cortex/align.py in automatic(subject, xfmname, reference, noclean, bbrtype, pre_flirt_args, use_fs_bbr)
#     259                 raise IOError('Error calling BBR flirt')
#     260
# --> 261             x = np.loadtxt(os.path.join(cache, "out.mat"))
#     262             # Pass transform as FROM epi TO anat; transform will be inverted
#     263             # back to anat-to-epi, standard direction for pycortex internal
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
# ...

# %%
eg = nb.load('../../data/brains/braindiff_i_mni.nii.gz')

# %%
gb = nl.plotting.plot_glass_brain(eg)

# %%
gb.savefig('/Users/paxtonfitzpatrick/Desktop/braindiff_i_glassbrain.pdf')
