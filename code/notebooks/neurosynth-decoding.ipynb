# %%
import numpy as np
import pandas as pd
import nibabel as nb
import hypertools as hyp
import pickle
import os
import joblib
import neurosynth as ns
from scipy.spatial.distance import cdist
from scipy.stats import pearsonr
import importlib.util
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
annot_dir = '../../data/annotations_dfs/'
ep_model_dir = '../../data/models/episodes/'
ep_traj_dir = os.path.join(ep_model_dir, 't100_w50/', 'trajectories')
ep_seg_dir = os.path.join(ep_model_dir, 't100_w50/', 'events')
ep_emb_dir = os.path.join(ep_model_dir, 't100_w50/', 'embeddings', 'k:1000')
rec_model_dir = '../../data/models/participants/'
rec_traj_dir = os.path.join(rec_model_dir, 'trajectories')
rec_seg_dir = os.path.join(rec_model_dir, 'events', 'k:1000')
rec_emb_dir = os.path.join(rec_model_dir, 'embeddings', 'k:1000')
pickle_dir = '../../data/pickles/'
braindata_dir = '../../data/brains/'
fig_dir = '../../figures/'
brainfig_dir = os.path.join(fig_dir,'brains/')

# %%
pycnifti = nb.load(braindata_dir+'away_from_volume.nii.gz')

# %%
pycnifti_mni = nb.load(braindata_dir+'away_from_mni.nii.gz')

# %%
# ns_datset = ns.Dataset('../neurosynth/data/database.txt', feature_filename='../neurosynth/data/features.txt')

# %%
# ns_dataset.save(pickle_dir+'neurosynth_dataset.p')

# %%
ns_dataset = ns.base.dataset.Dataset.load(pickle_dir+'neurosynth_dataset.p')

# %%
# decoder = ns.analysis.decode.Decoder(ns_dataset)

# %%
# joblib.dump(decoder, braindata_dir+'neurosynth_decoder.joblib')
# Out:
# ['../../data/brains/neurosynth_decoder.joblib']

# %%
decoder = joblib.load(braindata_dir+'neurosynth_decoder.joblib')

# %%
decoded_away_from = decoder.decode([braindata_dir+'away_from_mni.nii.gz'], 
                                   save=braindata_dir+'away_from_decoding.txt')

# %%
decoded_away_from.sort_values(decoded_away_from.columns[0], ascending=False)
# Out:
#                          ../../data/brains/away_from_mni.nii.gz
# speech                                                   0.2134
# listening                                                0.1875
# sentences                                                0.1839
# language                                                 0.1833
# superior temporal                                        0.1806
# auditory                                                 0.1735
# temporal gyrus                                           0.1714
# speech production                                        0.1706
# spoken                                                   0.1671
# stg                                                      0.1619
# comprehension                                            0.1609
# listened                                                 0.1598
# vocal                                                    0.1592
# speaker                                                  0.1569
# production                                               0.1547
# sounds                                                   0.1545
# speech perception                                        0.1533
# auditory cortex                                          0.1524
# linguistic                                               0.1519
# acoustic                                                 0.1517
# gyrus stg                                                0.1506
# syntactic                                                0.1479
# primary auditory                                         0.1454
# sentence                                                 0.1441
# language comprehension                                   0.1425
# broca                                                    0.1399
# heard                                                    0.1384
# temporal                                                 0.1383
# planum                                                   0.1359
# voice                                                    0.1358
# ...                                                         ...
# locations                                               -0.0966
# choice                                                  -0.0967
# behavior                                                -0.0975
# visuo spatial                                           -0.0979
# posterior parietal                                      -0.0985
# making                                                  -0.0999
# fronto parietal                                         -0.1010
# trial                                                   -0.1018
# decision making                                         -0.1026
# parietal network                                        -0.1048
# retrosplenial                                           -0.1054
# superior frontal                                        -0.1061
# memory                                                  -0.1063
# frontal parietal                                        -0.1064
# frontoparietal network                                  -0.1081
# trials                                                  -0.1087
# cue                                                     -0.1091
# parietal cortex                                         -0.1113
# attentional                                             -0.1158
# parietal                                                -0.1160
# attention                                               -0.1161
# frontoparietal                                          -0.1186
# navigation                                              -0.1214
# prefrontal cortex                                       -0.1216
# spatial                                                 -0.1253
# dorsolateral                                            -0.1263
# prefrontal                                              -0.1316
# virtual                                                 -0.1343
# dorsolateral prefrontal                                 -0.1348
# precuneus                                               -0.1454
#
# [3228 rows x 1 columns]

# %%
decoded_braindiff_d = decoder.decode([braindata_dir+'braindiff_d_mni.nii.gz'], 
                                   save=braindata_dir+'braindiff_d_decoding.txt')

# %%
del_diff_dec = decoded_braindiff_d.sort_values(decoded_braindiff_d.columns[0], ascending=False)

# %%
decoded_braindiff_i = decoder.decode([braindata_dir+'braindiff_i_mni.nii.gz'], 
                                   save=braindata_dir+'braindiff_i_decoding.txt')

# %%
imm_diff_dec = decoded_braindiff_i.sort_values(decoded_braindiff_i.columns[0], ascending=False)

# %%
(imm_diff_dec[imm_diff_dec.columns[0]] - del_diff_dec[del_diff_dec.columns[0]]).sort_values(ascending=False)
# Out:
# mental states              0.0087
# state                      0.0085
# mind                       0.0082
# theory mind                0.0081
# states                     0.0080
# resting                    0.0075
# mode network               0.0073
# resting state              0.0073
# default                    0.0070
# tom                        0.0069
# network dmn                0.0069
# default mode               0.0069
# mind tom                   0.0069
# dmn                        0.0067
# theory                     0.0066
# mode                       0.0066
# speech                     0.0065
# listening                  0.0064
# functional connectivity    0.0063
# mental state               0.0063
# medial prefrontal          0.0063
# temporal gyrus             0.0063
# autobiographical           0.0063
# connectivity               0.0061
# posterior cingulate        0.0060
# state functional           0.0060
# comprehension              0.0060
# dmpfc                      0.0059
# self                       0.0058
# positive                   0.0058
#                             ...
# tasks                     -0.0068
# parietal frontal          -0.0068
# spatial attention         -0.0068
# numerical                 -0.0068
# frontal parietal          -0.0071
# parietal network          -0.0074
# task                      -0.0075
# occipito                  -0.0075
# superior parietal         -0.0075
# occipital                 -0.0076
# fronto parietal           -0.0076
# occipito temporal         -0.0076
# spatial                   -0.0077
# working                   -0.0078
# working memory            -0.0078
# frontoparietal            -0.0078
# frontoparietal network    -0.0078
# posterior parietal        -0.0080
# color                     -0.0080
# shape                     -0.0081
# attentional               -0.0081
# objects                   -0.0081
# parietal cortex           -0.0082
# parietal                  -0.0085
# object                    -0.0087
# sulcus ips                -0.0087
# visual                    -0.0087
# ips                       -0.0089
# intraparietal             -0.0096
# intraparietal sulcus      -0.0098
# Length: 3228, dtype: float64
