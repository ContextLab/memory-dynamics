# %%
import numpy as np
import pandas as pd
import nibabel as nb
import hypertools as hyp
import pickle
import os
import joblib
import neurosynth as ns
from scipy.spatial.distance import cdist
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
annot_dir = '../../data/annotations_dfs/'
ep_model_dir = '../../data/models/episodes/'
ep_traj_dir = os.path.join(ep_model_dir, 't100_w50/', 'trajectories')
ep_seg_dir = os.path.join(ep_model_dir, 't100_w50/', 'events')
ep_emb_dir = os.path.join(ep_model_dir, 't100_w50/', 'embeddings', 'k:1000')
rec_model_dir = '../../data/models/participants/'
rec_traj_dir = os.path.join(rec_model_dir, 'trajectories')
rec_seg_dir = os.path.join(rec_model_dir, 'events', 'k:1000')
rec_emb_dir = os.path.join(rec_model_dir, 'embeddings', 'k:1000')
pickle_dir = '../../data/pickles/'
braindata_dir = '../../data/brains/'
fig_dir = '../../figures/'
brainfig_dir = os.path.join(fig_dir,'brains/')

# %%
decoder = joblib.load(braindata_dir+'neurosynth_decoder.joblib')

# %%
# transform from pycortex space to MNI space
s1_to_mni = np.load(braindata_dir+'mni_xfm.npy')

# topic dimension voxel weights
episode_topic_voxweights = {ep : np.load(os.path.join(braindata_dir, ep, 'topic_voxelweights.npy'))
                            for ep in ['atlep1','atlep2','arrdev']}

# pycortex mask
mask = np.load(braindata_dir+'mask.npy')

# %%
def standardize_brainspace(vol, xfm=s1_to_mni):
    mni_space = cortex.mni.transform_to_mni(vol, xfm)
    std_brain = se.helpers._std((2,2,2))
    res_mni = nl.image.resample_img(mni_space, target_affine=std_brain.affine, target_shape=std_brain.shape)
    return res_mni

# %%
# ns_datset = ns.Dataset('../neurosynth/data/database.txt', feature_filename='../neurosynth/data/features.txt')
# ns_dataset.save(pickle_dir+'neurosynth_dataset.p')
# ns_dataset = ns.base.dataset.Dataset.load(pickle_dir+'neurosynth_dataset.p')

# %%
# decoder = ns.analysis.decode.Decoder(ns_dataset)
# joblib.dump(decoder, braindata_dir+'neurosynth_decoder.joblib')

# %%
# decoded_away_from = decoder.decode([braindata_dir+'away_from_mni.nii.gz'], 
#                                    save=braindata_dir+'away_from_decoding.txt')

# %%
# decoded_away_from.sort_values(decoded_away_from.columns[0], ascending=False)

# %%
# decoded_braindiff_d = decoder.decode([braindata_dir+'braindiff_d_mni.nii.gz'], 
#                                    save=braindata_dir+'braindiff_d_decoding.txt')

# %%
# decoded_braindiff_i = decoder.decode([braindata_dir+'braindiff_i_mni.nii.gz'], 
#                                    save=braindata_dir+'braindiff_i_decoding.txt')

# %%
# decoded_imm_del = decoder.decode([braindata_dir+'imm_del_mni.nii.gz'], 
#                                    save=braindata_dir+'imm_del_decoding.txt')

# %%
# decoded_del_imm = decoder.decode([braindata_dir+'del_imm_mni.nii.gz'], 
#                                    save=braindata_dir+'del_imm_decoding.txt')

# %%
# decoded_imm_del.sort_values(decoded_imm_del.columns[0], ascending=False)

# %%
# decoded_del_imm.sort_values(decoded_del_imm.columns[0], ascending=False)

# %%
# best remembered content overall from atlep1
decoded_a1remembered = decoder.decode([braindata_dir+'a1_mni.nii.gz'], 
                                      save=braindata_dir+'a1remembered_decoding.txt')

# %%
decoded_a1remembered.sort_values(decoded_a1remembered.columns[0], ascending=False)
# Out:
#                          ../../data/brains/a1_mni.nii.gz
# dorsolateral                                      0.1593
# dorsolateral prefrontal                           0.1569
# dlpfc                                             0.1371
# frontoparietal                                    0.1356
# parietal cortex                                   0.1344
# cortex dlpfc                                      0.1286
# intraparietal sulcus                              0.1273
# intraparietal                                     0.1251
# fronto parietal                                   0.1247
# working memory                                    0.1240
# working                                           0.1231
# task                                              0.1225
# trials                                            0.1206
# parietal                                          0.1202
# posterior parietal                                0.1197
# performance                                       0.1185
# numbers                                           0.1169
# prefrontal                                        0.1167
# frontoparietal network                            0.1166
# ips                                               0.1159
# decision making                                   0.1151
# executive                                         0.1151
# parietal network                                  0.1133
# numerical                                         0.1133
# rule                                              0.1118
# choice                                            0.1111
# choices                                           0.1101
# frontal parietal                                  0.1086
# sulcus ips                                        0.1084
# attentional                                       0.1077
# ...                                                  ...
# mtg                                              -0.1250
# states                                           -0.1251
# acoustic                                         -0.1252
# mind tom                                         -0.1259
# heard                                            -0.1268
# auditory cortex                                  -0.1276
# gyrus stg                                        -0.1303
# linguistic                                       -0.1305
# primary auditory                                 -0.1335
# theory mind                                      -0.1339
# sts                                              -0.1350
# syntactic                                        -0.1360
# temporal sulcus                                  -0.1370
# auditory                                         -0.1382
# middle temporal                                  -0.1383
# stg                                              -0.1388
# spoken                                           -0.1390
# sounds                                           -0.1391
# speaker                                          -0.1399
# sentence                                         -0.1406
# language                                         -0.1418
# listened                                         -0.1495
# temporal                                         -0.1552
# mental states                                    -0.1594
# comprehension                                    -0.1633
# listening                                        -0.1660
# speech                                           -0.1724
# superior temporal                                -0.1726
# sentences                                        -0.1751
# temporal gyrus                                   -0.1760
#
# [3228 rows x 1 columns]

# %%
# best remembered content overall from atlep1
decoded_a1forgotten = decoder.decode([braindata_dir+'a1f_mni.nii.gz'], 
                                      save=braindata_dir+'a1forgotten_decoding.txt')

# %%
decoded_a1forgotten.sort_values(decoded_a1forgotten.columns[0], ascending=False)
# Out:
#                          ../../data/brains/a1f_mni.nii.gz
# temporal gyrus                                     0.1760
# sentences                                          0.1751
# superior temporal                                  0.1726
# speech                                             0.1724
# listening                                          0.1660
# comprehension                                      0.1633
# mental states                                      0.1594
# temporal                                           0.1552
# listened                                           0.1495
# language                                           0.1418
# sentence                                           0.1406
# speaker                                            0.1399
# sounds                                             0.1391
# spoken                                             0.1390
# stg                                                0.1388
# middle temporal                                    0.1383
# auditory                                           0.1382
# temporal sulcus                                    0.1370
# syntactic                                          0.1360
# sts                                                0.1350
# theory mind                                        0.1339
# primary auditory                                   0.1335
# linguistic                                         0.1305
# gyrus stg                                          0.1303
# auditory cortex                                    0.1276
# heard                                              0.1268
# mind tom                                           0.1259
# acoustic                                           0.1252
# states                                             0.1251
# mtg                                                0.1250
# ...                                                   ...
# attentional                                       -0.1077
# sulcus ips                                        -0.1084
# frontal parietal                                  -0.1086
# choices                                           -0.1101
# choice                                            -0.1111
# rule                                              -0.1118
# parietal network                                  -0.1133
# numerical                                         -0.1133
# decision making                                   -0.1151
# executive                                         -0.1151
# ips                                               -0.1159
# frontoparietal network                            -0.1166
# prefrontal                                        -0.1167
# numbers                                           -0.1169
# performance                                       -0.1185
# posterior parietal                                -0.1197
# parietal                                          -0.1202
# trials                                            -0.1206
# task                                              -0.1225
# working                                           -0.1231
# working memory                                    -0.1240
# fronto parietal                                   -0.1247
# intraparietal                                     -0.1251
# intraparietal sulcus                              -0.1273
# cortex dlpfc                                      -0.1286
# parietal cortex                                   -0.1344
# frontoparietal                                    -0.1356
# dlpfc                                             -0.1371
# dorsolateral prefrontal                           -0.1569
# dorsolateral                                      -0.1593
#
# [3228 rows x 1 columns]

# %%
# best remembered content overall from atlep1
decoded_a1diff = decoder.decode(['/Users/paxtonfitzpatrick/Desktop/a1_mni.nii.gz'], 
                                      save=braindata_dir+'a1diff_decoding.txt')

# %%
decoded_a1diff.sort_values(decoded_a1forgotten.columns[0], ascending=False)
# Out:
#                          /Users/paxtonfitzpatrick/Desktop/a1_mni.nii.gz
# dorsolateral                                                     0.1593
# dorsolateral prefrontal                                          0.1569
# dlpfc                                                            0.1371
# frontoparietal                                                   0.1356
# parietal cortex                                                  0.1344
# cortex dlpfc                                                     0.1286
# intraparietal sulcus                                             0.1273
# intraparietal                                                    0.1251
# fronto parietal                                                  0.1247
# working memory                                                   0.1240
# working                                                          0.1231
# task                                                             0.1225
# trials                                                           0.1206
# parietal                                                         0.1202
# posterior parietal                                               0.1197
# performance                                                      0.1185
# numbers                                                          0.1169
# prefrontal                                                       0.1167
# frontoparietal network                                           0.1166
# ips                                                              0.1159
# decision making                                                  0.1151
# executive                                                        0.1151
# parietal network                                                 0.1133
# numerical                                                        0.1133
# rule                                                             0.1118
# choice                                                           0.1111
# choices                                                          0.1101
# frontal parietal                                                 0.1086
# sulcus ips                                                       0.1084
# attentional                                                      0.1077
# ...                                                                 ...
# mtg                                                             -0.1250
# states                                                          -0.1251
# acoustic                                                        -0.1252
# mind tom                                                        -0.1259
# heard                                                           -0.1268
# auditory cortex                                                 -0.1276
# gyrus stg                                                       -0.1303
# linguistic                                                      -0.1305
# primary auditory                                                -0.1335
# theory mind                                                     -0.1339
# sts                                                             -0.1350
# syntactic                                                       -0.1360
# temporal sulcus                                                 -0.1370
# auditory                                                        -0.1382
# middle temporal                                                 -0.1383
# stg                                                             -0.1388
# spoken                                                          -0.1390
# sounds                                                          -0.1391
# speaker                                                         -0.1399
# sentence                                                        -0.1406
# language                                                        -0.1418
# listened                                                        -0.1495
# temporal                                                        -0.1552
# mental states                                                   -0.1594
# comprehension                                                   -0.1633
# listening                                                       -0.1660
# speech                                                          -0.1724
# superior temporal                                               -0.1726
# sentences                                                       -0.1751
# temporal gyrus                                                  -0.1760
#
# [3228 rows x 1 columns]

# %%
away_from_terms = pd.read_csv(braindata_dir+'away_from_decoding.txt')

# %%
away_from_terms.sort_values(away_from_terms.columns[1], ascending=True)
# Out:
#                       Feature  ../../data/brains/away_from_mni.nii.gz
# 2242                precuneus                                 -0.1454
# 889   dorsolateral prefrontal                                 -0.1348
# 3142                  virtual                                 -0.1343
# 2258               prefrontal                                 -0.1316
# 887              dorsolateral                                 -0.1263
# 2751                  spatial                                 -0.1253
# 2259        prefrontal cortex                                 -0.1216
# 1904               navigation                                 -0.1214
# 1207           frontoparietal                                 -0.1186
# 259                 attention                                 -0.1161
# 2084                 parietal                                 -0.1160
# 263               attentional                                 -0.1158
# 2085          parietal cortex                                 -0.1113
# 701                       cue                                 -0.1091
# 3036                   trials                                 -0.1087
# 1208   frontoparietal network                                 -0.1081
# 1201         frontal parietal                                 -0.1064
# 1776                   memory                                 -0.1063
# 2877         superior frontal                                 -0.1061
# 2539            retrosplenial                                 -0.1054
# 2093         parietal network                                 -0.1048
# 723           decision making                                 -0.1026
# 3034                    trial                                 -0.1018
# 1204          fronto parietal                                 -0.1010
# 1709                   making                                 -0.0999
# 2221       posterior parietal                                 -0.0985
# 3160            visuo spatial                                 -0.0979
# 306                  behavior                                 -0.0975
# 416                    choice                                 -0.0967
# 1676                locations                                 -0.0966
# ...                       ...                                     ...
# 3167                    voice                                  0.1358
# 2174                   planum                                  0.1359
# 2941                 temporal                                  0.1383
# 1327                    heard                                  0.1384
# 359                     broca                                  0.1399
# 1593   language comprehension                                  0.1425
# 2637                 sentence                                  0.1441
# 2285         primary auditory                                  0.1454
# 2905                syntactic                                  0.1479
# 1302                gyrus stg                                  0.1506
# 86                   acoustic                                  0.1517
# 1652               linguistic                                  0.1519
# 273           auditory cortex                                  0.1524
# 2772        speech perception                                  0.1533
# 2745                   sounds                                  0.1545
# 2314               production                                  0.1547
# 2757                  speaker                                  0.1569
# 3166                    vocal                                  0.1592
# 1658                 listened                                  0.1598
# 496             comprehension                                  0.1609
# 2796                      stg                                  0.1619
# 2779                   spoken                                  0.1671
# 2773        speech production                                  0.1706
# 2946           temporal gyrus                                  0.1714
# 272                  auditory                                  0.1735
# 2881        superior temporal                                  0.1806
# 1592                 language                                  0.1833
# 2639                sentences                                  0.1839
# 1659                listening                                  0.1875
# 2771                   speech                                  0.2134
#
# [3228 rows x 2 columns]

# %%
away_from_terms.sort_values(away_from_terms.columns[1], ascending=True)
# Out:
#                       Feature  ../../data/brains/away_from_mni.nii.gz
# 2242                precuneus                                 -0.1454
# 889   dorsolateral prefrontal                                 -0.1348
# 3142                  virtual                                 -0.1343
# 2258               prefrontal                                 -0.1316
# 887              dorsolateral                                 -0.1263
# 2751                  spatial                                 -0.1253
# 2259        prefrontal cortex                                 -0.1216
# 1904               navigation                                 -0.1214
# 1207           frontoparietal                                 -0.1186
# 259                 attention                                 -0.1161
# 2084                 parietal                                 -0.1160
# 263               attentional                                 -0.1158
# 2085          parietal cortex                                 -0.1113
# 701                       cue                                 -0.1091
# 3036                   trials                                 -0.1087
# 1208   frontoparietal network                                 -0.1081
# 1201         frontal parietal                                 -0.1064
# 1776                   memory                                 -0.1063
# 2877         superior frontal                                 -0.1061
# 2539            retrosplenial                                 -0.1054
# 2093         parietal network                                 -0.1048
# 723           decision making                                 -0.1026
# 3034                    trial                                 -0.1018
# 1204          fronto parietal                                 -0.1010
# 1709                   making                                 -0.0999
# 2221       posterior parietal                                 -0.0985
# 3160            visuo spatial                                 -0.0979
# 306                  behavior                                 -0.0975
# 416                    choice                                 -0.0967
# 1676                locations                                 -0.0966
# ...                       ...                                     ...
# 3167                    voice                                  0.1358
# 2174                   planum                                  0.1359
# 2941                 temporal                                  0.1383
# 1327                    heard                                  0.1384
# 359                     broca                                  0.1399
# 1593   language comprehension                                  0.1425
# 2637                 sentence                                  0.1441
# 2285         primary auditory                                  0.1454
# 2905                syntactic                                  0.1479
# 1302                gyrus stg                                  0.1506
# 86                   acoustic                                  0.1517
# 1652               linguistic                                  0.1519
# 273           auditory cortex                                  0.1524
# 2772        speech perception                                  0.1533
# 2745                   sounds                                  0.1545
# 2314               production                                  0.1547
# 2757                  speaker                                  0.1569
# 3166                    vocal                                  0.1592
# 1658                 listened                                  0.1598
# 496             comprehension                                  0.1609
# 2796                      stg                                  0.1619
# 2779                   spoken                                  0.1671
# 2773        speech production                                  0.1706
# 2946           temporal gyrus                                  0.1714
# 272                  auditory                                  0.1735
# 2881        superior temporal                                  0.1806
# 1592                 language                                  0.1833
# 2639                sentences                                  0.1839
# 1659                listening                                  0.1875
# 2771                   speech                                  0.2134
#
# [3228 rows x 2 columns]
