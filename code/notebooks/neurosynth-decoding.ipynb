# %%
import numpy as np
import pandas as pd
import hypertools as hyp
import pickle
import os
import neurosynth as ns
from scipy.spatial.distance import cdist
from scipy.stats import pearsonr
import importlib.util
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
annot_dir = '../../data/annotations_dfs/'
ep_model_dir = '../../data/models/episodes/'
ep_traj_dir = os.path.join(ep_model_dir, 't100_w50/', 'trajectories')
ep_seg_dir = os.path.join(ep_model_dir, 't100_w50/', 'events')
ep_emb_dir = os.path.join(ep_model_dir, 't100_w50/', 'embeddings', 'k:1000')
rec_model_dir = '../../data/models/participants/'
rec_traj_dir = os.path.join(rec_model_dir, 'trajectories')
rec_seg_dir = os.path.join(rec_model_dir, 'events', 'k:1000')
rec_emb_dir = os.path.join(rec_model_dir, 'embeddings', 'k:1000')
pickle_dir = '../../data/pickles/'
braindata_dir = '../../data/brains/'
fig_dir = '../../figures/'
brainfig_dir = os.path.join(fig_dir,'brains/')

# %%
ns_dataset = ns.base.dataset.Dataset.load(pickle_dir+'neurosynth_dataset.p')

# %%
decoder = ns.analysis.decode.Decoder(ns_dataset)

# %%
decoded_away_from = decoder.decode([braindata_dir+'away_from_volume.nii.gz'], 
                                   save=braindata_dir+'away_from_decoding.txt')

# %%
decoder.masker = ns.base.mask.Masker(braindata_dir+'away_from_volume.nii.gz')

# %%
decoder.masker.get_image()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-24ec369f188a> in <module>()
# ----> 1 decoder.masker.get_mask()
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/neurosynth/base/mask.py in get_mask(self, layers, output, in_global_mask)
#     219         # Always include the original volume
#     220         layers.append(self.full)
# --> 221         layers = np.vstack(layers).T.astype(bool)
#     222         mask = layers.all(axis=1)
#     223         mask = self.get_image(mask, output)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/numpy/core/shape_base.py in vstack(tup)
#     232
#     233     """
# --> 234     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     235
#     236 def hstack(tup):
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
decoder.masker.volume.shape
# Out:
# (91, 109, 91)

# %%
np.load(braindata_dir+'mask.npy').shape
# Out:
# (31, 100, 100)
